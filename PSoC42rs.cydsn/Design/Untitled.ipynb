# %%
deg_per_rev=1.8
steps_per_rev=360/deg_per_rev #steps
microstepping=8
target_spd=600 #rpm
target_rps=target_spd/60*microstepping
print("Target RPS: ",target_rps ,"microsteps:",microstepping)
# Out:
# Target RPS:  80.0 microsteps: 8

# %%
#pulser
time_encoder_read = 100#us
freq=24000000
period=2400
pulser_freq=freq/period
print("pulserFreq:",pulser_freq)
# Out:
# pulserFreq: 10000.0

# %%
maxspd_pulser=pulserFreq
